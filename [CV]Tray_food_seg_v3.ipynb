# %% [markdown]
# # Data Import & Installazione librerie Python

# %%
# mount della cartella di Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# unzip data e clean
# !unzip -a "drive/My Drive/data_IPCV/data.zip" -d "dataset"
# !rm -rf image-dataset/__MACOSX # rimuovo una cartella inutile creata con lo zip
# Out:
# Archive:  drive/My Drive/data_IPCV/data.zip
#   inflating: dataset/TrayDataset/TrayDataset/XTest/1005a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTest/2002a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTest/3004a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTest/4003a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTest/5006a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTest/6004a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTest/7010a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTest/8006a.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a56.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a57.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a58.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a59.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a60.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a61.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a62.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a63.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a64.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a65.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a66.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a67.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a68.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a69.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a70.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a71.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a72.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1001a73.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a56.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a57.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a58.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a59.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a60.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a61.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a62.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a63.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a64.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a65.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a66.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a67.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a68.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a69.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a70.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a71.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a72.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/1006a73.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a56.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a57.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a58.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a59.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a60.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a61.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a62.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a63.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a64.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a65.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a66.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a67.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a68.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a69.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a70.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a71.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a72.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2001a73.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a56.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a57.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a58.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a59.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a60.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a61.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a62.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a63.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a64.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a65.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a66.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a67.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a68.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a69.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a70.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a71.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a72.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/2003a73.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a56.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a57.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a58.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a59.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a60.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a61.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a62.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a63.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a64.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a65.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a66.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a67.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a68.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a69.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a70.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a71.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a72.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/3001a73.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a56.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a57.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a58.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a59.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a60.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a61.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a62.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a63.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a64.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a65.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a66.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a67.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a68.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a69.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a70.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a71.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a72.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4001a73.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a01.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a02.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a03.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a04.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a05.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a06.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a07.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a08.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a09.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a10.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a11.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a12.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a13.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a14.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a15.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a16.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a17.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a18.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a19.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a20.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a21.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a22.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a23.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a24.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a25.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a26.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a27.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a28.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a29.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a30.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a31.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a32.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a33.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a34.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a35.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a36.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a37.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a38.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a39.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a40.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a41.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a42.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a43.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a44.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a45.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a46.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a47.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a48.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a49.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a50.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a51.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a52.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a53.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a54.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a55.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a56.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a57.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a58.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a59.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a60.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a61.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a62.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a63.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a64.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a65.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a66.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a67.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a68.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a69.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a70.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a71.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a72.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/4002a73.JPG  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a56.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a57.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a58.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a59.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a60.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a61.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a62.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a63.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a64.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a65.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a66.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a67.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a68.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a69.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a70.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a71.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a72.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5001a73.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a01.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a02.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a03.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a04.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a05.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a06.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a07.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a08.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a09.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a10.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a11.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a12.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a13.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a14.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a15.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a16.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a17.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a18.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a19.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a20.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a21.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a22.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a23.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a24.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a25.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a26.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a27.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a28.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a29.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a30.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a31.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a32.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a33.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a34.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a35.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a36.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a37.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a38.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a39.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a40.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a41.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a42.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a43.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a44.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a45.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a46.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a47.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a48.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a49.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a50.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a51.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a52.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a53.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a54.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a55.jpg  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/XTrain/5007a56.jpg  [binary]
# ...
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a05.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a06.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a07.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a08.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a09.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a10.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a11.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a12.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a13.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a14.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a15.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a16.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a17.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a18.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a19.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a20.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a21.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a22.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a23.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a24.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a25.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a26.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a27.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a28.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a29.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a30.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a31.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a32.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a33.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a34.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a35.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a36.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a37.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a38.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a39.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a40.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a41.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a42.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a43.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a44.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a45.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a46.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a47.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a48.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a49.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a50.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a51.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a52.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a53.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a54.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a55.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a56.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a57.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a58.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a59.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a60.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a61.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a62.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a63.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a64.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a65.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a66.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a67.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a68.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a69.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a70.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a71.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a72.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8001a73.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a01.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a02.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a03.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a04.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a05.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a06.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a07.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a08.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a09.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a10.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a11.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a12.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a13.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a14.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a15.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a16.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a17.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a18.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a19.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a20.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a21.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a22.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a23.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a24.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a25.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a26.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a27.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a28.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a29.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a30.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a31.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a32.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a33.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a34.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a35.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a36.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a37.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a38.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a39.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a40.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a41.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a42.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a43.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a44.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a45.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a46.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a47.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a48.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a49.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a50.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a51.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a52.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a53.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a54.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a55.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a56.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a57.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a58.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a59.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a60.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a61.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a62.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a63.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a64.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a65.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a66.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a67.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a68.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a69.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a70.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a71.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a72.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8005a73.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a01.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a02.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a03.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a04.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a05.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a06.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a07.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a08.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a09.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a10.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a11.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a12.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a13.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a14.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a15.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a16.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a17.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a18.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a19.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a20.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a21.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a22.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a23.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a24.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a25.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a26.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a27.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a28.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a29.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a30.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a31.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a32.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a33.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a34.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a35.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a36.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a37.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a38.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a39.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a40.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a41.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a42.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a43.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a44.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a45.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a46.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a47.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a48.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a49.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a50.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a51.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a52.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a53.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a54.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a55.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a56.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a57.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a58.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a59.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a60.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a61.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a62.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a63.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a64.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a65.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a66.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a67.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a68.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a69.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a70.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a71.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a72.png  [binary]
#   inflating: dataset/TrayDataset/TrayDataset/yTrain/8007a73.png  [binary]
#   inflating: dataset/classes.csv     [binary]

# %%
# installazione libreria utility
# !pip install -U segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading https://files.pythonhosted.org/packages/da/b9/4a183518c21689a56b834eaaa45cad242d9ec09a4360b5b10139f23c63f4/segmentation_models-1.0.1-py3-none-any.whl
# Collecting efficientnet==1.0.0
#   Downloading https://files.pythonhosted.org/packages/97/82/f3ae07316f0461417dc54affab6e86ab188a5a22f33176d35271628b96e0/efficientnet-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Collecting image-classifiers==1.0.0
#   Downloading https://files.pythonhosted.org/packages/81/98/6f84720e299a4942ab80df5f76ab97b7828b24d1de5e9b2cbbe6073228b7/image_classifiers-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.16.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.18.4)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (7.0.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.2.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.12.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Installing collected packages: efficientnet, image-classifiers, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 segmentation-models-1.0.1

# %%
# upgrade ram
a = []
while(1):
    a.append('1'*100000)

# %% [markdown]
# # Data Exploration

# %%
# import basilari
# %tensorflow_version 1.x
# %load_ext tensorboard
import pandas as pd
import numpy as np
from numpy.random import uniform
import tensorflow as tf
import keras.backend as K
import segmentation_models as sm
import matplotlib.pyplot as plt
import scipy.io as sio
from imageio import imread
from os import listdir
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,TensorBoard
import matplotlib.pyplot as plt
from keras.models import load_model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
path = './dataset/'
data_class =pd.read_csv(path+'classes.csv')
data_class.head()
# Out:
#    _id      _class       _name
# 0    0  background  background
# 1    1        tray        tray
# 2    2     cutlery     cutlery
# 3    3        form        form
# 4    4       straw       straw

# %%
# visualizzo una img da x_train e y_train
originale = imread(path+'TrayDataset/TrayDataset/XTrain/1001a03.jpg')
attesa = imread(path+'TrayDataset/TrayDataset/yTrain/1001a03.png')
plt.subplot(1,2,1); plt.imshow(originale); plt.title('originale');
plt.subplot(1,2,2); plt.imshow(attesa); plt.title('attesa');

# %% [markdown]
# # Data preprocessing &  Bulding model

# %%
# Definizione backbone, caricamento IO, e preprocess dell'input
# BACKBONE = 'inceptionv3'
BACKBONE = 'vgg19'
preprocess_input = sm.get_preprocessing(BACKBONE) # attenzione, non utilizzata -> da problemi!

# load your data
x_train_val = []
for image in listdir(path+'TrayDataset/TrayDataset/XTrain/'):
    x_train_val.append((image,imread(path+'TrayDataset/TrayDataset/XTrain/'+image),image[0]))
                                       
y_train_val =[]
for image in listdir(path+'TrayDataset/TrayDataset/yTrain/'):
    y_train_val.append((image,imread(path+'TrayDataset/TrayDataset/yTrain/'+image),image[0]))

# %% [markdown]
# ### 1.   sort x and y
# ### 2.   train and test split stratified
# ### 3.   conversion to numpy array

# %%
# ordino i due vettori e ricontrollo
x_train_val.sort(key = lambda x: x[0])
y_train_val.sort(key = lambda x: x[0])
x_Train_Val = [i[1] for i in x_train_val]
y_Train_Val = [i[1] for i in y_train_val]

# mi prendo i label per fare una stratificazione
x_label = [i[2] for i in x_train_val]

del x_train_val
del y_train_val
# riduco in 0-1

x_Train_Val = np.array(x_Train_Val).astype('float32')/255
# splitto in training e validation -> aggiunta stratificazione sul label elemento[0] del nome img
X_train, X_val, y_train, y_val = train_test_split(x_Train_Val, y_Train_Val, test_size=0.25, random_state=17, stratify = x_label)
X_train = np.array(X_train)
X_val = np.array(X_val)
y_train = np.array(y_train)
y_val = np.array(y_val)

# %%
#visualizzo
plt.subplot(1,2,1); plt.imshow(X_train[0]); plt.title('originale');
plt.subplot(1,2,2); plt.imshow(y_train[0]); plt.title('attesa');

# %% [markdown]
# *   ***shape check***

# %%
# verifico la dimensione del X_train e X_val
print(str(X_train.shape)+ ' '+ str(X_val.shape)+' '+str(type(X_train)))
# Out:
# (930, 256, 416, 3) (311, 256, 416, 3) <class 'numpy.ndarray'>

# %% [markdown]
# ### ***One hot encoding***  for y_train image

# %%
def one_hot_it(label, label_values):
    """
    Convert a segmentation image label array to one-hot format
    by replacing each pixel value with a vector of length num_classes
    # Arguments
        label: The 2D array segmentation image label
        label_values
        
    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of num_classes
    """
    #print('Start One-Hot Vectorizing...')
    semantic_map = []
    for colour in label_values:
        equality = np.equal(label, colour)
        class_map = np.all(equality, axis = -1)
        semantic_map.append(class_map)
    semantic_map = np.stack(semantic_map, axis=-1)
    #print('Done..')
    return semantic_map

# %%
background=[0,0,0]
tray=[1,1,1]
cutler=[2,2,2]
form=[3,3,3]
straw=[4,4,4]
meatball=[5,5,5]
beef=[6,6,6]
roastlamb=[7,7,7]
beeftomatocasserole=[8,8,8]
ham=[9,9,9]
bean=[10,10,10]
cucumber=[11,11,11]
leaf=[12,12,12]
tomato=[13,13,13]
boiledrice=[14,14,14]
beefmexicanmeatballs=[15,15,15]
spinachandpumpkinrisotto=[16,16,16]
bakedfish=[17,17,17]
gravy=[18,18,18]
zucchini=[19,19,19]
carrot=[20,20,20]
broccoli=[21,21,21]
pumpkin=[22,22,22]
celery=[23,23,23]
sandwich=[24,24,24]
sidesalad=[25,25,25]
tartaresauce=[26,26,26]
jacketpotato=[27,27,27]
creamedpotato=[28,28,28]
bread=[29,29,29]
margarine=[30,30,30]
soup=[31,31,31]
apple=[32,32,32]
cannedfruit=[33,33,33]
milk=[34,34,34]
vanillayogurt=[35,35,35]
jelly=[36,36,36]
custard=[37,37,37]
lemonsponge=[38,38,38]
juice=[39,39,39]
applejuice=[40,40,40]
orangejuice=[41,41,41]
water=[42,42,42]

# We dont want to classify unlabelled.it will only make our dataset more unbalanced than it already is
label_values = [background,tray,cutler,form,straw,meatball,beef,roastlamb,beeftomatocasserole,ham,bean,cucumber,leaf,tomato,boiledrice,
beefmexicanmeatballs,spinachandpumpkinrisotto,bakedfish,gravy,zucchini,carrot,broccoli,pumpkin,celery,sandwich,sidesalad,
tartaresauce,jacketpotato,creamedpotato,bread,margarine,soup,apple,cannedfruit,milk,vanillayogurt,jelly,custard,lemonsponge,
juice,applejuice,orangejuice,water]

# %%
pre = [one_hot_it(y_train[i],label_values) for i in range(len(y_train))]
del y_train
y_train_norm = np.array(pre)
del pre
pree = [one_hot_it(y_val[i],label_values) for i in range(len(y_val))]
del y_val
y_val_norm = np.array(pree)
del pree

# %% [markdown]
# # **Loss definition** & **hpam search coarse to fine**

# %%
###### definizione loss e iou
"""
def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
  union = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1) - intersection
  return (intersection+smooth)/(union+smooth)
# verificato -> problema
"""
def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3]) # ottiene un numero per ogni img 
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  return iou # => verificato...  dovrebbe funzionare correttamente

#    IoU = (|X &amp; Y|)/ (|X or Y|)
def iou_coef_loss(y_true, y_pred):
  return -iou_coef(y_true, y_pred)

# %%
# ricerca hpam <-> Coarse to fine classica
COARSE_TRAIN_EPOCHS = 10
FINER_TRAIN_EPOCHS = 20 # chiamato epochs dopo
MAX_RANGE = 20

# %%
# define model

meanIOU = tf.keras.metrics.MeanIoU(num_classes=43)
for i in range(0,MAX_RANGE):
  lr = 10**uniform(-3, -2) # COARSE TO FINE [COARSE] => NEW INTERVAL: -3, -2 <-> OLD INTERVAL : -7 -1 
  # lr = ... # FINER 
  adam = Adam(learning_rate = lr)
  model = sm.Unet(BACKBONE, encoder_weights='imagenet', input_shape = (256, 416, 3), encoder_freeze = True, classes=43, activation='softmax')
  model.compile(
      adam,
      loss=sm.losses.JaccardLoss(), #loss = 'categorical_crossentropy',
      metrics = ['accuracy', sm.metrics.IOUScore(), meanIOU, iou_coef] # metrics=[sm.metrics.iou_score]
      )
  if i == 0:
    print(model.summary()) # model.summary() non visualizzo sempre per comodità 
  print('********** lr = '+str(lr)+' **********')
  model.fit(
      x=X_train,
      y=y_train_norm,
      batch_size=16,
      epochs=COARSE_TRAIN_EPOCHS,
      validation_data=(X_val,y_val_norm))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 6s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 416, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 416, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 416, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 128, 208, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 208, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 208, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 64, 104, 128) 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 104, 256) 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 32, 52, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 52, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 16, 26, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 16, 26, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 8, 13, 512)   0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# center_block1_conv (Conv2D)     (None, 8, 13, 512)   2359296     block5_pool[0][0]
# __________________________________________________________________________________________________
# center_block1_bn (BatchNormaliz (None, 8, 13, 512)   2048        center_block1_conv[0][0]
# __________________________________________________________________________________________________
# center_block1_relu (Activation) (None, 8, 13, 512)   0           center_block1_bn[0][0]
# __________________________________________________________________________________________________
# center_block2_conv (Conv2D)     (None, 8, 13, 512)   2359296     center_block1_relu[0][0]
# __________________________________________________________________________________________________
# center_block2_bn (BatchNormaliz (None, 8, 13, 512)   2048        center_block2_conv[0][0]
# __________________________________________________________________________________________________
# center_block2_relu (Activation) (None, 8, 13, 512)   0           center_block2_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 16, 26, 512)  0           center_block2_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 16, 26, 1024) 0           decoder_stage0_upsampling[0][0]
#                                                                  block5_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, 16, 26, 256)  2359296     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 16, 26, 256)  1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 16, 26, 256)  0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, 16, 26, 256)  589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 16, 26, 256)  1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 16, 26, 256)  0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 32, 52, 256)  0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 32, 52, 768)  0           decoder_stage1_upsampling[0][0]
#                                                                  block4_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, 32, 52, 128)  884736      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 32, 52, 128)  512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 32, 52, 128)  0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, 32, 52, 128)  147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 32, 52, 128)  512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 32, 52, 128)  0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 64, 104, 128) 0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 64, 104, 384) 0           decoder_stage2_upsampling[0][0]
#                                                                  block3_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, 64, 104, 64)  221184      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 64, 104, 64)  256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 64, 104, 64)  0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, 64, 104, 64)  36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 64, 104, 64)  256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 64, 104, 64)  0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 128, 208, 64) 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 128, 208, 192 0           decoder_stage3_upsampling[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, 128, 208, 32) 55296       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 128, 208, 32) 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 128, 208, 32) 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, 128, 208, 32) 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 128, 208, 32) 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 128, 208, 32) 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 256, 416, 32) 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, 256, 416, 16) 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 256, 416, 16) 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 256, 416, 16) 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, 256, 416, 16) 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 256, 416, 16) 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 256, 416, 16) 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 256, 416, 43) 6235        decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 256, 416, 43) 0           final_conv[0][0]
# ==================================================================================================
# Total params: 29,068,059
# Trainable params: 9,039,643
# Non-trainable params: 20,028,416
# __________________________________________________________________________________________________
# None
# ********** lr = 0.004406586853009122 **********
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 74s 79ms/step - loss: 0.9023 - accuracy: 0.7836 - iou_score: 0.0985 - mean_io_u: 0.4885 - iou_coef: 0.5851 - val_loss: 0.9970 - val_accuracy: 0.0336 - val_iou_score: 0.0030 - val_mean_io_u: 0.4891 - val_iou_coef: 0.0173
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7209 - accuracy: 0.8576 - iou_score: 0.2783 - mean_io_u: 0.4890 - iou_coef: 0.7502 - val_loss: 0.9948 - val_accuracy: 0.0201 - val_iou_score: 0.0051 - val_mean_io_u: 0.4888 - val_iou_coef: 0.0091
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.6132 - accuracy: 0.8710 - iou_score: 0.3835 - mean_io_u: 0.4890 - iou_coef: 0.7715 - val_loss: 0.9547 - val_accuracy: 0.2407 - val_iou_score: 0.0458 - val_mean_io_u: 0.4899 - val_iou_coef: 0.1346
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5377 - accuracy: 0.9173 - iou_score: 0.4592 - mean_io_u: 0.4916 - iou_coef: 0.8491 - val_loss: 0.8287 - val_accuracy: 0.7375 - val_iou_score: 0.1710 - val_mean_io_u: 0.4947 - val_iou_coef: 0.5823
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4890 - accuracy: 0.9600 - iou_score: 0.5071 - mean_io_u: 0.4989 - iou_coef: 0.9202 - val_loss: 0.6093 - val_accuracy: 0.8983 - val_iou_score: 0.3896 - val_mean_io_u: 0.5052 - val_iou_coef: 0.8065
# Epoch 6/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.2978 - accuracy: 0.9684 - iou_score: 0.7000 - mean_io_u: 0.5244 - iou_coef: 0.9376 - val_loss: 0.3505 - val_accuracy: 0.9152 - val_iou_score: 0.6484 - val_mean_io_u: 0.5506 - val_iou_coef: 0.8427
# Epoch 7/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.2103 - accuracy: 0.9754 - iou_score: 0.7852 - mean_io_u: 0.5747 - iou_coef: 0.9516 - val_loss: 0.2324 - val_accuracy: 0.9623 - val_iou_score: 0.7666 - val_mean_io_u: 0.5972 - val_iou_coef: 0.9274
# Epoch 8/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.1949 - accuracy: 0.9790 - iou_score: 0.8007 - mean_io_u: 0.6171 - iou_coef: 0.9585 - val_loss: 0.2102 - val_accuracy: 0.9699 - val_iou_score: 0.7884 - val_mean_io_u: 0.6349 - val_iou_coef: 0.9409
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.1866 - accuracy: 0.9806 - iou_score: 0.8093 - mean_io_u: 0.6509 - iou_coef: 0.9616 - val_loss: 0.2004 - val_accuracy: 0.9745 - val_iou_score: 0.7982 - val_mean_io_u: 0.6654 - val_iou_coef: 0.9500
# Epoch 10/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.1837 - accuracy: 0.9820 - iou_score: 0.8112 - mean_io_u: 0.6786 - iou_coef: 0.9641 - val_loss: 0.2027 - val_accuracy: 0.9746 - val_iou_score: 0.7960 - val_mean_io_u: 0.6908 - val_iou_coef: 0.9503
# ********** lr = 0.0014647475072083914 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 64s 69ms/step - loss: 0.9430 - accuracy: 0.6629 - iou_score: 0.0574 - mean_io_u: 0.6861 - iou_coef: 0.3374 - val_loss: 0.9936 - val_accuracy: 0.1514 - val_iou_score: 0.0064 - val_mean_io_u: 0.6769 - val_iou_coef: 0.0452
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.8493 - accuracy: 0.8839 - iou_score: 0.1509 - mean_io_u: 0.6685 - iou_coef: 0.7699 - val_loss: 0.9784 - val_accuracy: 0.2906 - val_iou_score: 0.0216 - val_mean_io_u: 0.6611 - val_iou_coef: 0.1492
# Epoch 3/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.7111 - accuracy: 0.9320 - iou_score: 0.2876 - mean_io_u: 0.6544 - iou_coef: 0.8609 - val_loss: 0.9179 - val_accuracy: 0.6654 - val_iou_score: 0.0820 - val_mean_io_u: 0.6482 - val_iou_coef: 0.4517
# Epoch 4/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.6048 - accuracy: 0.9472 - iou_score: 0.3927 - mean_io_u: 0.6425 - iou_coef: 0.8951 - val_loss: 0.7604 - val_accuracy: 0.7103 - val_iou_score: 0.2396 - val_mean_io_u: 0.6371 - val_iou_coef: 0.5270
# Epoch 5/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.5222 - accuracy: 0.9610 - iou_score: 0.4745 - mean_io_u: 0.6321 - iou_coef: 0.9214 - val_loss: 0.7150 - val_accuracy: 0.8671 - val_iou_score: 0.2846 - val_mean_io_u: 0.6275 - val_iou_coef: 0.7439
# Epoch 6/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.4843 - accuracy: 0.9640 - iou_score: 0.5121 - mean_io_u: 0.6231 - iou_coef: 0.9290 - val_loss: 0.5479 - val_accuracy: 0.9307 - val_iou_score: 0.4508 - val_mean_io_u: 0.6191 - val_iou_coef: 0.8653
# Epoch 7/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4578 - accuracy: 0.9676 - iou_score: 0.5390 - mean_io_u: 0.6153 - iou_coef: 0.9363 - val_loss: 0.4830 - val_accuracy: 0.9630 - val_iou_score: 0.5156 - val_mean_io_u: 0.6118 - val_iou_coef: 0.9264
# Epoch 8/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.4402 - accuracy: 0.9728 - iou_score: 0.5558 - mean_io_u: 0.6085 - iou_coef: 0.9459 - val_loss: 0.4604 - val_accuracy: 0.9669 - val_iou_score: 0.5379 - val_mean_io_u: 0.6055 - val_iou_coef: 0.9344
# Epoch 9/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4264 - accuracy: 0.9746 - iou_score: 0.5691 - mean_io_u: 0.6026 - iou_coef: 0.9493 - val_loss: 0.4667 - val_accuracy: 0.9664 - val_iou_score: 0.5316 - val_mean_io_u: 0.6001 - val_iou_coef: 0.9340
# Epoch 10/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.4178 - accuracy: 0.9769 - iou_score: 0.5775 - mean_io_u: 0.5977 - iou_coef: 0.9540 - val_loss: 0.4397 - val_accuracy: 0.9727 - val_iou_score: 0.5583 - val_mean_io_u: 0.5954 - val_iou_coef: 0.9463
# ********** lr = 0.0032220910229318485 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 65s 70ms/step - loss: 0.9041 - accuracy: 0.7692 - iou_score: 0.0966 - mean_io_u: 0.5929 - iou_coef: 0.4847 - val_loss: 0.9972 - val_accuracy: 0.0157 - val_iou_score: 0.0027 - val_mean_io_u: 0.5899 - val_iou_coef: 0.0078
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7208 - accuracy: 0.9336 - iou_score: 0.2780 - mean_io_u: 0.5871 - iou_coef: 0.8663 - val_loss: 0.9770 - val_accuracy: 0.2848 - val_iou_score: 0.0230 - val_mean_io_u: 0.5849 - val_iou_coef: 0.1591
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.6159 - accuracy: 0.9463 - iou_score: 0.3825 - mean_io_u: 0.5828 - iou_coef: 0.8968 - val_loss: 0.9233 - val_accuracy: 0.5957 - val_iou_score: 0.0768 - val_mean_io_u: 0.5809 - val_iou_coef: 0.4182
# Epoch 4/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.5597 - accuracy: 0.9527 - iou_score: 0.4380 - mean_io_u: 0.5792 - iou_coef: 0.9095 - val_loss: 0.6780 - val_accuracy: 0.8904 - val_iou_score: 0.3213 - val_mean_io_u: 0.5776 - val_iou_coef: 0.7926
# Epoch 5/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.5100 - accuracy: 0.9622 - iou_score: 0.4875 - mean_io_u: 0.5761 - iou_coef: 0.9263 - val_loss: 0.5968 - val_accuracy: 0.8912 - val_iou_score: 0.4024 - val_mean_io_u: 0.5748 - val_iou_coef: 0.7875
# Epoch 6/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.4551 - accuracy: 0.9664 - iou_score: 0.5445 - mean_io_u: 0.5737 - iou_coef: 0.9344 - val_loss: 0.6329 - val_accuracy: 0.9171 - val_iou_score: 0.3669 - val_mean_io_u: 0.5730 - val_iou_coef: 0.8225
# Epoch 7/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.2498 - accuracy: 0.9675 - iou_score: 0.7480 - mean_io_u: 0.5768 - iou_coef: 0.9374 - val_loss: 0.3625 - val_accuracy: 0.9133 - val_iou_score: 0.6385 - val_mean_io_u: 0.5823 - val_iou_coef: 0.8404
# Epoch 8/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.2164 - accuracy: 0.9731 - iou_score: 0.7816 - mean_io_u: 0.5878 - iou_coef: 0.9482 - val_loss: 0.2262 - val_accuracy: 0.9513 - val_iou_score: 0.7737 - val_mean_io_u: 0.5935 - val_iou_coef: 0.9072
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2116 - accuracy: 0.9732 - iou_score: 0.7844 - mean_io_u: 0.5990 - iou_coef: 0.9473 - val_loss: 0.2175 - val_accuracy: 0.9644 - val_iou_score: 0.7824 - val_mean_io_u: 0.6044 - val_iou_coef: 0.9320
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2152 - accuracy: 0.9741 - iou_score: 0.7820 - mean_io_u: 0.6098 - iou_coef: 0.9500 - val_loss: 0.2076 - val_accuracy: 0.9716 - val_iou_score: 0.7925 - val_mean_io_u: 0.6150 - val_iou_coef: 0.9462
# ********** lr = 0.0019366687517469762 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 64s 69ms/step - loss: 0.9314 - accuracy: 0.5233 - iou_score: 0.0691 - mean_io_u: 0.6146 - iou_coef: 0.2769 - val_loss: 0.9834 - val_accuracy: 0.2467 - val_iou_score: 0.0166 - val_mean_io_u: 0.6125 - val_iou_coef: 0.1359
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7984 - accuracy: 0.8266 - iou_score: 0.2012 - mean_io_u: 0.6104 - iou_coef: 0.6676 - val_loss: 0.9598 - val_accuracy: 0.5964 - val_iou_score: 0.0403 - val_mean_io_u: 0.6085 - val_iou_coef: 0.3602
# Epoch 3/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.6625 - accuracy: 0.9457 - iou_score: 0.3362 - mean_io_u: 0.6067 - iou_coef: 0.8916 - val_loss: 0.9044 - val_accuracy: 0.5932 - val_iou_score: 0.0955 - val_mean_io_u: 0.6050 - val_iou_coef: 0.3049
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5736 - accuracy: 0.9570 - iou_score: 0.4236 - mean_io_u: 0.6034 - iou_coef: 0.9155 - val_loss: 0.7379 - val_accuracy: 0.8825 - val_iou_score: 0.2614 - val_mean_io_u: 0.6019 - val_iou_coef: 0.7467
# Epoch 5/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.5321 - accuracy: 0.9626 - iou_score: 0.4648 - mean_io_u: 0.6003 - iou_coef: 0.9272 - val_loss: 0.7369 - val_accuracy: 0.8757 - val_iou_score: 0.2631 - val_mean_io_u: 0.5989 - val_iou_coef: 0.7345
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5086 - accuracy: 0.9646 - iou_score: 0.4882 - mean_io_u: 0.5974 - iou_coef: 0.9299 - val_loss: 0.5607 - val_accuracy: 0.9347 - val_iou_score: 0.4384 - val_mean_io_u: 0.5961 - val_iou_coef: 0.8721
# Epoch 7/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.4771 - accuracy: 0.9710 - iou_score: 0.5195 - mean_io_u: 0.5948 - iou_coef: 0.9428 - val_loss: 0.4959 - val_accuracy: 0.9597 - val_iou_score: 0.5029 - val_mean_io_u: 0.5936 - val_iou_coef: 0.9219
# Epoch 8/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4600 - accuracy: 0.9753 - iou_score: 0.5343 - mean_io_u: 0.5925 - iou_coef: 0.9504 - val_loss: 0.4832 - val_accuracy: 0.9644 - val_iou_score: 0.5155 - val_mean_io_u: 0.5915 - val_iou_coef: 0.9304
# Epoch 9/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.3676 - accuracy: 0.9761 - iou_score: 0.6316 - mean_io_u: 0.5914 - iou_coef: 0.9529 - val_loss: 0.4861 - val_accuracy: 0.9679 - val_iou_score: 0.5127 - val_mean_io_u: 0.5932 - val_iou_coef: 0.9375
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2107 - accuracy: 0.9780 - iou_score: 0.7869 - mean_io_u: 0.5965 - iou_coef: 0.9569 - val_loss: 0.2135 - val_accuracy: 0.9759 - val_iou_score: 0.7864 - val_mean_io_u: 0.6001 - val_iou_coef: 0.9530
# ********** lr = 0.0019189836042674895 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 65s 70ms/step - loss: 0.9273 - accuracy: 0.7431 - iou_score: 0.0736 - mean_io_u: 0.5996 - iou_coef: 0.4455 - val_loss: 0.9996 - val_accuracy: 0.0095 - val_iou_score: 4.1561e-04 - val_mean_io_u: 0.5979 - val_iou_coef: 0.0049
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7804 - accuracy: 0.9237 - iou_score: 0.2188 - mean_io_u: 0.5964 - iou_coef: 0.8424 - val_loss: 0.9603 - val_accuracy: 0.3207 - val_iou_score: 0.0397 - val_mean_io_u: 0.5951 - val_iou_coef: 0.1815
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.6380 - accuracy: 0.9430 - iou_score: 0.3587 - mean_io_u: 0.5939 - iou_coef: 0.8859 - val_loss: 0.9543 - val_accuracy: 0.4124 - val_iou_score: 0.0457 - val_mean_io_u: 0.5927 - val_iou_coef: 0.2488
# Epoch 4/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.5495 - accuracy: 0.9498 - iou_score: 0.4474 - mean_io_u: 0.5915 - iou_coef: 0.9024 - val_loss: 0.7657 - val_accuracy: 0.7960 - val_iou_score: 0.2335 - val_mean_io_u: 0.5904 - val_iou_coef: 0.5963
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4900 - accuracy: 0.9598 - iou_score: 0.5053 - mean_io_u: 0.5894 - iou_coef: 0.9220 - val_loss: 0.6011 - val_accuracy: 0.9094 - val_iou_score: 0.3971 - val_mean_io_u: 0.5885 - val_iou_coef: 0.7966
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4746 - accuracy: 0.9637 - iou_score: 0.5213 - mean_io_u: 0.5876 - iou_coef: 0.9291 - val_loss: 0.5346 - val_accuracy: 0.9280 - val_iou_score: 0.4629 - val_mean_io_u: 0.5867 - val_iou_coef: 0.8480
# Epoch 7/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4398 - accuracy: 0.9686 - iou_score: 0.5559 - mean_io_u: 0.5859 - iou_coef: 0.9381 - val_loss: 0.4932 - val_accuracy: 0.9510 - val_iou_score: 0.5043 - val_mean_io_u: 0.5852 - val_iou_coef: 0.9049
# Epoch 8/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4400 - accuracy: 0.9703 - iou_score: 0.5553 - mean_io_u: 0.5844 - iou_coef: 0.9407 - val_loss: 0.4516 - val_accuracy: 0.9537 - val_iou_score: 0.5456 - val_mean_io_u: 0.5838 - val_iou_coef: 0.9108
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4370 - accuracy: 0.9713 - iou_score: 0.5609 - mean_io_u: 0.5832 - iou_coef: 0.9434 - val_loss: 0.4476 - val_accuracy: 0.9644 - val_iou_score: 0.5497 - val_mean_io_u: 0.5826 - val_iou_coef: 0.9304
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4290 - accuracy: 0.9699 - iou_score: 0.5659 - mean_io_u: 0.5820 - iou_coef: 0.9408 - val_loss: 0.4455 - val_accuracy: 0.9674 - val_iou_score: 0.5518 - val_mean_io_u: 0.5815 - val_iou_coef: 0.9364
# ********** lr = 0.0033975090388673277 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 65s 70ms/step - loss: 0.9132 - accuracy: 0.7683 - iou_score: 0.0876 - mean_io_u: 0.5807 - iou_coef: 0.5316 - val_loss: 0.9974 - val_accuracy: 0.0537 - val_iou_score: 0.0025 - val_mean_io_u: 0.5797 - val_iou_coef: 0.0274
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7374 - accuracy: 0.9212 - iou_score: 0.2620 - mean_io_u: 0.5787 - iou_coef: 0.8444 - val_loss: 0.9855 - val_accuracy: 0.3414 - val_iou_score: 0.0145 - val_mean_io_u: 0.5778 - val_iou_coef: 0.0996
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5919 - accuracy: 0.9471 - iou_score: 0.4052 - mean_io_u: 0.5770 - iou_coef: 0.8973 - val_loss: 0.8959 - val_accuracy: 0.2284 - val_iou_score: 0.1042 - val_mean_io_u: 0.5762 - val_iou_coef: 0.1277
# Epoch 4/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.5181 - accuracy: 0.9603 - iou_score: 0.4787 - mean_io_u: 0.5755 - iou_coef: 0.9224 - val_loss: 0.7809 - val_accuracy: 0.7437 - val_iou_score: 0.2184 - val_mean_io_u: 0.5747 - val_iou_coef: 0.5157
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4525 - accuracy: 0.9688 - iou_score: 0.5436 - mean_io_u: 0.5741 - iou_coef: 0.9370 - val_loss: 0.6065 - val_accuracy: 0.9233 - val_iou_score: 0.3918 - val_mean_io_u: 0.5735 - val_iou_coef: 0.8406
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4138 - accuracy: 0.9708 - iou_score: 0.5818 - mean_io_u: 0.5735 - iou_coef: 0.9429 - val_loss: 0.4908 - val_accuracy: 0.9563 - val_iou_score: 0.5067 - val_mean_io_u: 0.5737 - val_iou_coef: 0.9109
# Epoch 7/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2542 - accuracy: 0.9757 - iou_score: 0.7422 - mean_io_u: 0.5750 - iou_coef: 0.9520 - val_loss: 0.2991 - val_accuracy: 0.9559 - val_iou_score: 0.6988 - val_mean_io_u: 0.5774 - val_iou_coef: 0.9150
# Epoch 8/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.1722 - accuracy: 0.9782 - iou_score: 0.8236 - mean_io_u: 0.5801 - iou_coef: 0.9566 - val_loss: 0.2037 - val_accuracy: 0.9749 - val_iou_score: 0.7933 - val_mean_io_u: 0.5829 - val_iou_coef: 0.9506
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.1803 - accuracy: 0.9803 - iou_score: 0.8147 - mean_io_u: 0.5857 - iou_coef: 0.9606 - val_loss: 0.2005 - val_accuracy: 0.9683 - val_iou_score: 0.7965 - val_mean_io_u: 0.5883 - val_iou_coef: 0.9382
# Epoch 10/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.1781 - accuracy: 0.9809 - iou_score: 0.8188 - mean_io_u: 0.5910 - iou_coef: 0.9621 - val_loss: 0.1928 - val_accuracy: 0.9736 - val_iou_score: 0.8043 - val_mean_io_u: 0.5937 - val_iou_coef: 0.9485
# ********** lr = 0.004678417789358925 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 65s 70ms/step - loss: 0.9018 - accuracy: 0.7417 - iou_score: 0.0989 - mean_io_u: 0.5936 - iou_coef: 0.5367 - val_loss: 0.9994 - val_accuracy: 0.0059 - val_iou_score: 5.7670e-04 - val_mean_io_u: 0.5926 - val_iou_coef: 0.0029
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7230 - accuracy: 0.8493 - iou_score: 0.2754 - mean_io_u: 0.5916 - iou_coef: 0.7368 - val_loss: 0.9948 - val_accuracy: 0.0540 - val_iou_score: 0.0051 - val_mean_io_u: 0.5907 - val_iou_coef: 0.0275
# Epoch 3/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.5918 - accuracy: 0.9230 - iou_score: 0.4058 - mean_io_u: 0.5898 - iou_coef: 0.8573 - val_loss: 0.9279 - val_accuracy: 0.4069 - val_iou_score: 0.0722 - val_mean_io_u: 0.5890 - val_iou_coef: 0.2574
# Epoch 4/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.5320 - accuracy: 0.9509 - iou_score: 0.4640 - mean_io_u: 0.5884 - iou_coef: 0.9058 - val_loss: 0.7672 - val_accuracy: 0.5311 - val_iou_score: 0.2324 - val_mean_io_u: 0.5878 - val_iou_coef: 0.3615
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.3111 - accuracy: 0.9608 - iou_score: 0.6862 - mean_io_u: 0.5887 - iou_coef: 0.9236 - val_loss: 0.3996 - val_accuracy: 0.9132 - val_iou_score: 0.6008 - val_mean_io_u: 0.5904 - val_iou_coef: 0.8405
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2352 - accuracy: 0.9675 - iou_score: 0.7619 - mean_io_u: 0.5920 - iou_coef: 0.9368 - val_loss: 0.2833 - val_accuracy: 0.9509 - val_iou_score: 0.7168 - val_mean_io_u: 0.5936 - val_iou_coef: 0.9060
# Epoch 7/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2316 - accuracy: 0.9704 - iou_score: 0.7647 - mean_io_u: 0.5954 - iou_coef: 0.9407 - val_loss: 0.2755 - val_accuracy: 0.9401 - val_iou_score: 0.7243 - val_mean_io_u: 0.5971 - val_iou_coef: 0.8875
# Epoch 8/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2141 - accuracy: 0.9752 - iou_score: 0.7830 - mean_io_u: 0.5987 - iou_coef: 0.9507 - val_loss: 0.2659 - val_accuracy: 0.9592 - val_iou_score: 0.7343 - val_mean_io_u: 0.6005 - val_iou_coef: 0.9216
# Epoch 9/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.1894 - accuracy: 0.9791 - iou_score: 0.8076 - mean_io_u: 0.6022 - iou_coef: 0.9586 - val_loss: 0.2113 - val_accuracy: 0.9734 - val_iou_score: 0.7881 - val_mean_io_u: 0.6040 - val_iou_coef: 0.9479
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2088 - accuracy: 0.9744 - iou_score: 0.7865 - mean_io_u: 0.6056 - iou_coef: 0.9492 - val_loss: 0.2891 - val_accuracy: 0.8791 - val_iou_score: 0.7107 - val_mean_io_u: 0.6073 - val_iou_coef: 0.7853
# ********** lr = 0.002820183914879663 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 65s 70ms/step - loss: 0.9192 - accuracy: 0.7459 - iou_score: 0.0813 - mean_io_u: 0.6069 - iou_coef: 0.5130 - val_loss: 0.9986 - val_accuracy: 0.0176 - val_iou_score: 0.0014 - val_mean_io_u: 0.6059 - val_iou_coef: 0.0089
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7691 - accuracy: 0.8359 - iou_score: 0.2295 - mean_io_u: 0.6050 - iou_coef: 0.7092 - val_loss: 0.9620 - val_accuracy: 0.4092 - val_iou_score: 0.0381 - val_mean_io_u: 0.6042 - val_iou_coef: 0.2417
# Epoch 3/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.6249 - accuracy: 0.9055 - iou_score: 0.3722 - mean_io_u: 0.6034 - iou_coef: 0.8233 - val_loss: 0.9057 - val_accuracy: 0.5613 - val_iou_score: 0.0943 - val_mean_io_u: 0.6027 - val_iou_coef: 0.3491
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5313 - accuracy: 0.9307 - iou_score: 0.4656 - mean_io_u: 0.6019 - iou_coef: 0.8680 - val_loss: 0.8231 - val_accuracy: 0.8300 - val_iou_score: 0.1768 - val_mean_io_u: 0.6012 - val_iou_coef: 0.6829
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4744 - accuracy: 0.9455 - iou_score: 0.5227 - mean_io_u: 0.6005 - iou_coef: 0.8938 - val_loss: 0.6240 - val_accuracy: 0.8995 - val_iou_score: 0.3743 - val_mean_io_u: 0.5999 - val_iou_coef: 0.8055
# Epoch 6/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.3039 - accuracy: 0.9484 - iou_score: 0.6927 - mean_io_u: 0.6000 - iou_coef: 0.9012 - val_loss: 0.4491 - val_accuracy: 0.9299 - val_iou_score: 0.5512 - val_mean_io_u: 0.6011 - val_iou_coef: 0.8675
# Epoch 7/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.2213 - accuracy: 0.9524 - iou_score: 0.7746 - mean_io_u: 0.6022 - iou_coef: 0.9086 - val_loss: 0.3105 - val_accuracy: 0.9383 - val_iou_score: 0.6882 - val_mean_io_u: 0.6032 - val_iou_coef: 0.8827
# Epoch 8/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2155 - accuracy: 0.9546 - iou_score: 0.7788 - mean_io_u: 0.6042 - iou_coef: 0.9122 - val_loss: 0.2203 - val_accuracy: 0.9502 - val_iou_score: 0.7775 - val_mean_io_u: 0.6054 - val_iou_coef: 0.9053
# Epoch 9/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.1997 - accuracy: 0.9589 - iou_score: 0.7962 - mean_io_u: 0.6066 - iou_coef: 0.9207 - val_loss: 0.2154 - val_accuracy: 0.9400 - val_iou_score: 0.7819 - val_mean_io_u: 0.6077 - val_iou_coef: 0.8871
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.1946 - accuracy: 0.9595 - iou_score: 0.8009 - mean_io_u: 0.6089 - iou_coef: 0.9215 - val_loss: 0.2249 - val_accuracy: 0.9542 - val_iou_score: 0.7736 - val_mean_io_u: 0.6100 - val_iou_coef: 0.9123
# ********** lr = 0.0010710250697689768 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 65s 70ms/step - loss: 0.9529 - accuracy: 0.6737 - iou_score: 0.0473 - mean_io_u: 0.6097 - iou_coef: 0.2240 - val_loss: 0.9747 - val_accuracy: 0.1100 - val_iou_score: 0.0251 - val_mean_io_u: 0.6090 - val_iou_coef: 0.0431
# Epoch 2/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.8618 - accuracy: 0.8640 - iou_score: 0.1379 - mean_io_u: 0.6083 - iou_coef: 0.7256 - val_loss: 0.9665 - val_accuracy: 0.5226 - val_iou_score: 0.0335 - val_mean_io_u: 0.6076 - val_iou_coef: 0.1848
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7811 - accuracy: 0.9314 - iou_score: 0.2188 - mean_io_u: 0.6069 - iou_coef: 0.8528 - val_loss: 0.8860 - val_accuracy: 0.8549 - val_iou_score: 0.1141 - val_mean_io_u: 0.6062 - val_iou_coef: 0.6448
# Epoch 4/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.6568 - accuracy: 0.9512 - iou_score: 0.3418 - mean_io_u: 0.6056 - iou_coef: 0.8972 - val_loss: 0.8143 - val_accuracy: 0.8717 - val_iou_score: 0.1860 - val_mean_io_u: 0.6049 - val_iou_coef: 0.7059
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5483 - accuracy: 0.9624 - iou_score: 0.4487 - mean_io_u: 0.6042 - iou_coef: 0.9230 - val_loss: 0.7359 - val_accuracy: 0.9328 - val_iou_score: 0.2641 - val_mean_io_u: 0.6035 - val_iou_coef: 0.7419
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4884 - accuracy: 0.9706 - iou_score: 0.5081 - mean_io_u: 0.6029 - iou_coef: 0.9397 - val_loss: 0.5918 - val_accuracy: 0.9526 - val_iou_score: 0.4072 - val_mean_io_u: 0.6022 - val_iou_coef: 0.8901
# Epoch 7/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4708 - accuracy: 0.9721 - iou_score: 0.5244 - mean_io_u: 0.6016 - iou_coef: 0.9439 - val_loss: 0.5040 - val_accuracy: 0.9486 - val_iou_score: 0.4945 - val_mean_io_u: 0.6010 - val_iou_coef: 0.8991
# Epoch 8/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4373 - accuracy: 0.9749 - iou_score: 0.5590 - mean_io_u: 0.6004 - iou_coef: 0.9493 - val_loss: 0.4753 - val_accuracy: 0.9640 - val_iou_score: 0.5226 - val_mean_io_u: 0.5997 - val_iou_coef: 0.9298
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4160 - accuracy: 0.9765 - iou_score: 0.5801 - mean_io_u: 0.5992 - iou_coef: 0.9528 - val_loss: 0.4459 - val_accuracy: 0.9669 - val_iou_score: 0.5522 - val_mean_io_u: 0.5986 - val_iou_coef: 0.9351
# Epoch 10/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4069 - accuracy: 0.9796 - iou_score: 0.5879 - mean_io_u: 0.5980 - iou_coef: 0.9588 - val_loss: 0.4500 - val_accuracy: 0.9744 - val_iou_score: 0.5478 - val_mean_io_u: 0.5974 - val_iou_coef: 0.9489
# ********** lr = 0.006982039083022547 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 66s 71ms/step - loss: 0.8870 - accuracy: 0.7099 - iou_score: 0.1136 - mean_io_u: 0.5969 - iou_coef: 0.4499 - val_loss: 0.9785 - val_accuracy: 0.1932 - val_iou_score: 0.0217 - val_mean_io_u: 0.5963 - val_iou_coef: 0.1058
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7168 - accuracy: 0.9128 - iou_score: 0.2815 - mean_io_u: 0.5958 - iou_coef: 0.8366 - val_loss: 0.9700 - val_accuracy: 0.1383 - val_iou_score: 0.0300 - val_mean_io_u: 0.5952 - val_iou_coef: 0.0736
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.6317 - accuracy: 0.9330 - iou_score: 0.3669 - mean_io_u: 0.5947 - iou_coef: 0.8739 - val_loss: 0.9355 - val_accuracy: 0.2473 - val_iou_score: 0.0644 - val_mean_io_u: 0.5942 - val_iou_coef: 0.1391
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5786 - accuracy: 0.9429 - iou_score: 0.4181 - mean_io_u: 0.5937 - iou_coef: 0.8915 - val_loss: 0.7062 - val_accuracy: 0.8249 - val_iou_score: 0.2937 - val_mean_io_u: 0.5933 - val_iou_coef: 0.7009
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4707 - accuracy: 0.9494 - iou_score: 0.5306 - mean_io_u: 0.5931 - iou_coef: 0.9038 - val_loss: 0.4884 - val_accuracy: 0.8860 - val_iou_score: 0.5135 - val_mean_io_u: 0.5937 - val_iou_coef: 0.7939
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2829 - accuracy: 0.9560 - iou_score: 0.7152 - mean_io_u: 0.5947 - iou_coef: 0.9138 - val_loss: 0.3049 - val_accuracy: 0.9407 - val_iou_score: 0.6968 - val_mean_io_u: 0.5959 - val_iou_coef: 0.8886
# Epoch 7/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2631 - accuracy: 0.9568 - iou_score: 0.7358 - mean_io_u: 0.5972 - iou_coef: 0.9182 - val_loss: 0.3375 - val_accuracy: 0.8407 - val_iou_score: 0.6639 - val_mean_io_u: 0.5985 - val_iou_coef: 0.7266
# Epoch 8/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2651 - accuracy: 0.9580 - iou_score: 0.7340 - mean_io_u: 0.6000 - iou_coef: 0.9198 - val_loss: 0.3376 - val_accuracy: 0.9281 - val_iou_score: 0.6638 - val_mean_io_u: 0.6015 - val_iou_coef: 0.8669
# Epoch 9/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.2447 - accuracy: 0.9628 - iou_score: 0.7523 - mean_io_u: 0.6031 - iou_coef: 0.9286 - val_loss: 0.3030 - val_accuracy: 0.9460 - val_iou_score: 0.6990 - val_mean_io_u: 0.6046 - val_iou_coef: 0.8987
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2523 - accuracy: 0.9622 - iou_score: 0.7455 - mean_io_u: 0.6062 - iou_coef: 0.9276 - val_loss: 0.3296 - val_accuracy: 0.9215 - val_iou_score: 0.6718 - val_mean_io_u: 0.6076 - val_iou_coef: 0.8552
# ********** lr = 0.005731486645996804 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 65s 70ms/step - loss: 0.8985 - accuracy: 0.7713 - iou_score: 0.1022 - mean_io_u: 0.6074 - iou_coef: 0.5538 - val_loss: 0.9984 - val_accuracy: 0.0249 - val_iou_score: 0.0016 - val_mean_io_u: 0.6067 - val_iou_coef: 0.0126
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.6942 - accuracy: 0.9018 - iou_score: 0.3048 - mean_io_u: 0.6060 - iou_coef: 0.8158 - val_loss: 0.9862 - val_accuracy: 0.0518 - val_iou_score: 0.0136 - val_mean_io_u: 0.6054 - val_iou_coef: 0.0264
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4898 - accuracy: 0.9444 - iou_score: 0.5101 - mean_io_u: 0.6050 - iou_coef: 0.8920 - val_loss: 0.9357 - val_accuracy: 0.3866 - val_iou_score: 0.0643 - val_mean_io_u: 0.6052 - val_iou_coef: 0.2438
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.3044 - accuracy: 0.9534 - iou_score: 0.6931 - mean_io_u: 0.6056 - iou_coef: 0.9090 - val_loss: 0.5953 - val_accuracy: 0.6245 - val_iou_score: 0.4054 - val_mean_io_u: 0.6060 - val_iou_coef: 0.4850
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2560 - accuracy: 0.9610 - iou_score: 0.7412 - mean_io_u: 0.6064 - iou_coef: 0.9242 - val_loss: 0.3476 - val_accuracy: 0.9177 - val_iou_score: 0.6522 - val_mean_io_u: 0.6068 - val_iou_coef: 0.8472
# Epoch 6/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.2230 - accuracy: 0.9689 - iou_score: 0.7714 - mean_io_u: 0.6073 - iou_coef: 0.9380 - val_loss: 0.2453 - val_accuracy: 0.9493 - val_iou_score: 0.7536 - val_mean_io_u: 0.6079 - val_iou_coef: 0.9029
# Epoch 7/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.2108 - accuracy: 0.9710 - iou_score: 0.7855 - mean_io_u: 0.6088 - iou_coef: 0.9432 - val_loss: 0.4163 - val_accuracy: 0.8451 - val_iou_score: 0.5837 - val_mean_io_u: 0.6098 - val_iou_coef: 0.7318
# Epoch 8/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.2270 - accuracy: 0.9659 - iou_score: 0.7702 - mean_io_u: 0.6106 - iou_coef: 0.9338 - val_loss: 0.2745 - val_accuracy: 0.9445 - val_iou_score: 0.7253 - val_mean_io_u: 0.6117 - val_iou_coef: 0.8949
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.1956 - accuracy: 0.9726 - iou_score: 0.8011 - mean_io_u: 0.6125 - iou_coef: 0.9452 - val_loss: 0.2086 - val_accuracy: 0.9676 - val_iou_score: 0.7911 - val_mean_io_u: 0.6133 - val_iou_coef: 0.9374
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.1976 - accuracy: 0.9740 - iou_score: 0.7985 - mean_io_u: 0.6142 - iou_coef: 0.9480 - val_loss: 0.3139 - val_accuracy: 0.9354 - val_iou_score: 0.6860 - val_mean_io_u: 0.6154 - val_iou_coef: 0.8794
# ********** lr = 0.0029282073046454685 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 66s 71ms/step - loss: 0.9252 - accuracy: 0.7638 - iou_score: 0.0752 - mean_io_u: 0.6152 - iou_coef: 0.4831 - val_loss: 0.9934 - val_accuracy: 0.0523 - val_iou_score: 0.0065 - val_mean_io_u: 0.6146 - val_iou_coef: 0.0265
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7763 - accuracy: 0.9209 - iou_score: 0.2236 - mean_io_u: 0.6140 - iou_coef: 0.8376 - val_loss: 0.9774 - val_accuracy: 0.3845 - val_iou_score: 0.0227 - val_mean_io_u: 0.6135 - val_iou_coef: 0.2066
# Epoch 3/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.6190 - accuracy: 0.9433 - iou_score: 0.3785 - mean_io_u: 0.6129 - iou_coef: 0.8876 - val_loss: 0.9144 - val_accuracy: 0.6087 - val_iou_score: 0.0854 - val_mean_io_u: 0.6124 - val_iou_coef: 0.4219
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5354 - accuracy: 0.9579 - iou_score: 0.4614 - mean_io_u: 0.6119 - iou_coef: 0.9167 - val_loss: 0.7338 - val_accuracy: 0.8381 - val_iou_score: 0.2660 - val_mean_io_u: 0.6114 - val_iou_coef: 0.7101
# Epoch 5/10
# ...
# Epoch 5/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.5661 - accuracy: 0.9627 - iou_score: 0.4313 - mean_io_u: 0.6192 - iou_coef: 0.9263 - val_loss: 0.6837 - val_accuracy: 0.8856 - val_iou_score: 0.3165 - val_mean_io_u: 0.6188 - val_iou_coef: 0.7750
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5252 - accuracy: 0.9686 - iou_score: 0.4717 - mean_io_u: 0.6183 - iou_coef: 0.9376 - val_loss: 0.5716 - val_accuracy: 0.9482 - val_iou_score: 0.4282 - val_mean_io_u: 0.6179 - val_iou_coef: 0.8996
# Epoch 7/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5156 - accuracy: 0.9689 - iou_score: 0.4808 - mean_io_u: 0.6175 - iou_coef: 0.9388 - val_loss: 0.5332 - val_accuracy: 0.9603 - val_iou_score: 0.4661 - val_mean_io_u: 0.6171 - val_iou_coef: 0.9234
# Epoch 8/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4851 - accuracy: 0.9740 - iou_score: 0.5108 - mean_io_u: 0.6167 - iou_coef: 0.9487 - val_loss: 0.4960 - val_accuracy: 0.9696 - val_iou_score: 0.5032 - val_mean_io_u: 0.6164 - val_iou_coef: 0.9409
# Epoch 9/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4810 - accuracy: 0.9748 - iou_score: 0.5156 - mean_io_u: 0.6160 - iou_coef: 0.9502 - val_loss: 0.4762 - val_accuracy: 0.9628 - val_iou_score: 0.5231 - val_mean_io_u: 0.6157 - val_iou_coef: 0.9279
# Epoch 10/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.2993 - accuracy: 0.9745 - iou_score: 0.6974 - mean_io_u: 0.6161 - iou_coef: 0.9496 - val_loss: 0.2553 - val_accuracy: 0.9707 - val_iou_score: 0.7462 - val_mean_io_u: 0.6171 - val_iou_coef: 0.9435
# ********** lr = 0.0023083764703885966 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 67s 72ms/step - loss: 0.9143 - accuracy: 0.6760 - iou_score: 0.0866 - mean_io_u: 0.6170 - iou_coef: 0.1941 - val_loss: 0.9933 - val_accuracy: 0.0431 - val_iou_score: 0.0067 - val_mean_io_u: 0.6165 - val_iou_coef: 0.0223
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7821 - accuracy: 0.8442 - iou_score: 0.2165 - mean_io_u: 0.6161 - iou_coef: 0.6557 - val_loss: 0.9776 - val_accuracy: 0.0861 - val_iou_score: 0.0224 - val_mean_io_u: 0.6157 - val_iou_coef: 0.0435
# Epoch 3/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.6451 - accuracy: 0.9187 - iou_score: 0.3532 - mean_io_u: 0.6153 - iou_coef: 0.8452 - val_loss: 0.9199 - val_accuracy: 0.2627 - val_iou_score: 0.0800 - val_mean_io_u: 0.6149 - val_iou_coef: 0.1510
# Epoch 4/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.5398 - accuracy: 0.9568 - iou_score: 0.4567 - mean_io_u: 0.6145 - iou_coef: 0.9148 - val_loss: 0.8128 - val_accuracy: 0.4631 - val_iou_score: 0.1870 - val_mean_io_u: 0.6142 - val_iou_coef: 0.2898
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4798 - accuracy: 0.9692 - iou_score: 0.5159 - mean_io_u: 0.6138 - iou_coef: 0.9390 - val_loss: 0.5841 - val_accuracy: 0.9350 - val_iou_score: 0.4155 - val_mean_io_u: 0.6135 - val_iou_coef: 0.8706
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4611 - accuracy: 0.9722 - iou_score: 0.5348 - mean_io_u: 0.6131 - iou_coef: 0.9449 - val_loss: 0.5072 - val_accuracy: 0.9595 - val_iou_score: 0.4914 - val_mean_io_u: 0.6128 - val_iou_coef: 0.9207
# Epoch 7/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4416 - accuracy: 0.9757 - iou_score: 0.5544 - mean_io_u: 0.6126 - iou_coef: 0.9515 - val_loss: 0.4574 - val_accuracy: 0.9676 - val_iou_score: 0.5413 - val_mean_io_u: 0.6123 - val_iou_coef: 0.9374
# Epoch 8/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.4213 - accuracy: 0.9791 - iou_score: 0.5753 - mean_io_u: 0.6121 - iou_coef: 0.9585 - val_loss: 0.4225 - val_accuracy: 0.9761 - val_iou_score: 0.5761 - val_mean_io_u: 0.6123 - val_iou_coef: 0.9528
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2281 - accuracy: 0.9789 - iou_score: 0.7674 - mean_io_u: 0.6131 - iou_coef: 0.9580 - val_loss: 0.2260 - val_accuracy: 0.9677 - val_iou_score: 0.7740 - val_mean_io_u: 0.6140 - val_iou_coef: 0.9371
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.1917 - accuracy: 0.9799 - iou_score: 0.8046 - mean_io_u: 0.6149 - iou_coef: 0.9599 - val_loss: 0.2221 - val_accuracy: 0.9754 - val_iou_score: 0.7776 - val_mean_io_u: 0.6158 - val_iou_coef: 0.9522
# ********** lr = 0.003246056430766828 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 66s 71ms/step - loss: 0.9284 - accuracy: 0.4898 - iou_score: 0.0722 - mean_io_u: 0.6158 - iou_coef: 0.2091 - val_loss: 0.9851 - val_accuracy: 0.1214 - val_iou_score: 0.0150 - val_mean_io_u: 0.6153 - val_iou_coef: 0.0649
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7586 - accuracy: 0.9116 - iou_score: 0.2408 - mean_io_u: 0.6149 - iou_coef: 0.8124 - val_loss: 0.9902 - val_accuracy: 0.0921 - val_iou_score: 0.0099 - val_mean_io_u: 0.6145 - val_iou_coef: 0.0445
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5973 - accuracy: 0.9527 - iou_score: 0.4006 - mean_io_u: 0.6140 - iou_coef: 0.9067 - val_loss: 0.9334 - val_accuracy: 0.4939 - val_iou_score: 0.0670 - val_mean_io_u: 0.6137 - val_iou_coef: 0.3150
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5090 - accuracy: 0.9638 - iou_score: 0.4875 - mean_io_u: 0.6133 - iou_coef: 0.9280 - val_loss: 0.7162 - val_accuracy: 0.8699 - val_iou_score: 0.2827 - val_mean_io_u: 0.6130 - val_iou_coef: 0.7623
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4695 - accuracy: 0.9704 - iou_score: 0.5255 - mean_io_u: 0.6126 - iou_coef: 0.9408 - val_loss: 0.5119 - val_accuracy: 0.9559 - val_iou_score: 0.4862 - val_mean_io_u: 0.6123 - val_iou_coef: 0.9138
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.3416 - accuracy: 0.9703 - iou_score: 0.6574 - mean_io_u: 0.6123 - iou_coef: 0.9411 - val_loss: 0.4340 - val_accuracy: 0.9420 - val_iou_score: 0.5666 - val_mean_io_u: 0.6126 - val_iou_coef: 0.8898
# Epoch 7/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.2227 - accuracy: 0.9728 - iou_score: 0.7736 - mean_io_u: 0.6131 - iou_coef: 0.9468 - val_loss: 0.2750 - val_accuracy: 0.9500 - val_iou_score: 0.7235 - val_mean_io_u: 0.6136 - val_iou_coef: 0.9060
# Epoch 8/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2108 - accuracy: 0.9752 - iou_score: 0.7866 - mean_io_u: 0.6141 - iou_coef: 0.9505 - val_loss: 0.2280 - val_accuracy: 0.9721 - val_iou_score: 0.7696 - val_mean_io_u: 0.6146 - val_iou_coef: 0.9455
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2040 - accuracy: 0.9778 - iou_score: 0.7923 - mean_io_u: 0.6151 - iou_coef: 0.9560 - val_loss: 0.2672 - val_accuracy: 0.9693 - val_iou_score: 0.7308 - val_mean_io_u: 0.6156 - val_iou_coef: 0.9397
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2301 - accuracy: 0.9746 - iou_score: 0.7665 - mean_io_u: 0.6161 - iou_coef: 0.9501 - val_loss: 0.2727 - val_accuracy: 0.9592 - val_iou_score: 0.7261 - val_mean_io_u: 0.6166 - val_iou_coef: 0.9218
# ********** lr = 0.004926340782322386 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 67s 72ms/step - loss: 0.9236 - accuracy: 0.7574 - iou_score: 0.0771 - mean_io_u: 0.6165 - iou_coef: 0.5697 - val_loss: 0.9991 - val_accuracy: 0.0160 - val_iou_score: 9.1885e-04 - val_mean_io_u: 0.6160 - val_iou_coef: 0.0081
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7470 - accuracy: 0.8734 - iou_score: 0.2524 - mean_io_u: 0.6156 - iou_coef: 0.7733 - val_loss: 0.9959 - val_accuracy: 0.0153 - val_iou_score: 0.0041 - val_mean_io_u: 0.6152 - val_iou_coef: 0.0080
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.6017 - accuracy: 0.9434 - iou_score: 0.3959 - mean_io_u: 0.6148 - iou_coef: 0.8924 - val_loss: 0.9610 - val_accuracy: 0.3474 - val_iou_score: 0.0391 - val_mean_io_u: 0.6146 - val_iou_coef: 0.1949
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5373 - accuracy: 0.9588 - iou_score: 0.4596 - mean_io_u: 0.6143 - iou_coef: 0.9208 - val_loss: 0.8409 - val_accuracy: 0.8347 - val_iou_score: 0.1591 - val_mean_io_u: 0.6141 - val_iou_coef: 0.7100
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.3458 - accuracy: 0.9630 - iou_score: 0.6534 - mean_io_u: 0.6143 - iou_coef: 0.9288 - val_loss: 0.4674 - val_accuracy: 0.8611 - val_iou_score: 0.5342 - val_mean_io_u: 0.6149 - val_iou_coef: 0.7539
# Epoch 6/10
# 930/930 [==============================] - 64s 68ms/step - loss: 0.2450 - accuracy: 0.9701 - iou_score: 0.7529 - mean_io_u: 0.6156 - iou_coef: 0.9415 - val_loss: 0.3080 - val_accuracy: 0.9533 - val_iou_score: 0.6939 - val_mean_io_u: 0.6164 - val_iou_coef: 0.9105
# Epoch 7/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2354 - accuracy: 0.9734 - iou_score: 0.7631 - mean_io_u: 0.6172 - iou_coef: 0.9483 - val_loss: 0.2457 - val_accuracy: 0.9689 - val_iou_score: 0.7554 - val_mean_io_u: 0.6181 - val_iou_coef: 0.9403
# Epoch 8/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2363 - accuracy: 0.9749 - iou_score: 0.7611 - mean_io_u: 0.6189 - iou_coef: 0.9512 - val_loss: 0.2539 - val_accuracy: 0.9682 - val_iou_score: 0.7474 - val_mean_io_u: 0.6197 - val_iou_coef: 0.9383
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2269 - accuracy: 0.9754 - iou_score: 0.7705 - mean_io_u: 0.6206 - iou_coef: 0.9519 - val_loss: 0.2433 - val_accuracy: 0.9696 - val_iou_score: 0.7580 - val_mean_io_u: 0.6214 - val_iou_coef: 0.9414
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.2240 - accuracy: 0.9761 - iou_score: 0.7733 - mean_io_u: 0.6223 - iou_coef: 0.9531 - val_loss: 0.2458 - val_accuracy: 0.9682 - val_iou_score: 0.7553 - val_mean_io_u: 0.6231 - val_iou_coef: 0.9388
# ********** lr = 0.0064624174886794665 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 66s 71ms/step - loss: 0.8800 - accuracy: 0.7844 - iou_score: 0.1203 - mean_io_u: 0.6230 - iou_coef: 0.5910 - val_loss: 0.9961 - val_accuracy: 0.0301 - val_iou_score: 0.0039 - val_mean_io_u: 0.6226 - val_iou_coef: 0.0153
# Epoch 2/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.7038 - accuracy: 0.8700 - iou_score: 0.2944 - mean_io_u: 0.6222 - iou_coef: 0.7686 - val_loss: 0.9889 - val_accuracy: 0.0448 - val_iou_score: 0.0110 - val_mean_io_u: 0.6218 - val_iou_coef: 0.0224
# Epoch 3/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.4977 - accuracy: 0.9399 - iou_score: 0.5018 - mean_io_u: 0.6215 - iou_coef: 0.8855 - val_loss: 0.9326 - val_accuracy: 0.3620 - val_iou_score: 0.0675 - val_mean_io_u: 0.6215 - val_iou_coef: 0.2199
# Epoch 4/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.3059 - accuracy: 0.9546 - iou_score: 0.6917 - mean_io_u: 0.6218 - iou_coef: 0.9131 - val_loss: 0.6061 - val_accuracy: 0.7694 - val_iou_score: 0.3935 - val_mean_io_u: 0.6222 - val_iou_coef: 0.6245
# Epoch 5/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.2639 - accuracy: 0.9617 - iou_score: 0.7324 - mean_io_u: 0.6225 - iou_coef: 0.9252 - val_loss: 0.3768 - val_accuracy: 0.8346 - val_iou_score: 0.6223 - val_mean_io_u: 0.6230 - val_iou_coef: 0.7161
# Epoch 6/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.2355 - accuracy: 0.9677 - iou_score: 0.7616 - mean_io_u: 0.6234 - iou_coef: 0.9373 - val_loss: 0.3786 - val_accuracy: 0.9099 - val_iou_score: 0.6209 - val_mean_io_u: 0.6240 - val_iou_coef: 0.8348
# Epoch 7/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.2576 - accuracy: 0.9660 - iou_score: 0.7394 - mean_io_u: 0.6244 - iou_coef: 0.9337 - val_loss: 0.4483 - val_accuracy: 0.8770 - val_iou_score: 0.5516 - val_mean_io_u: 0.6249 - val_iou_coef: 0.7811
# Epoch 8/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.2715 - accuracy: 0.9626 - iou_score: 0.7254 - mean_io_u: 0.6253 - iou_coef: 0.9266 - val_loss: 0.2992 - val_accuracy: 0.9514 - val_iou_score: 0.6998 - val_mean_io_u: 0.6256 - val_iou_coef: 0.9068
# Epoch 9/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.2254 - accuracy: 0.9719 - iou_score: 0.7708 - mean_io_u: 0.6261 - iou_coef: 0.9449 - val_loss: 0.2431 - val_accuracy: 0.9653 - val_iou_score: 0.7554 - val_mean_io_u: 0.6267 - val_iou_coef: 0.9329
# Epoch 10/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.2569 - accuracy: 0.9680 - iou_score: 0.7408 - mean_io_u: 0.6274 - iou_coef: 0.9372 - val_loss: 0.3643 - val_accuracy: 0.9147 - val_iou_score: 0.6347 - val_mean_io_u: 0.6279 - val_iou_coef: 0.8415
# ********** lr = 0.002872328489096505 **********
# Train on 930 samples, validate on 311 samples
# Epoch 1/10
# 930/930 [==============================] - 67s 72ms/step - loss: 0.9248 - accuracy: 0.7538 - iou_score: 0.0757 - mean_io_u: 0.6277 - iou_coef: 0.4732 - val_loss: 0.9978 - val_accuracy: 0.0347 - val_iou_score: 0.0022 - val_mean_io_u: 0.6272 - val_iou_coef: 0.0173
# Epoch 2/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.7538 - accuracy: 0.8892 - iou_score: 0.2458 - mean_io_u: 0.6268 - iou_coef: 0.7937 - val_loss: 0.9814 - val_accuracy: 0.2298 - val_iou_score: 0.0186 - val_mean_io_u: 0.6265 - val_iou_coef: 0.1244
# Epoch 3/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.5984 - accuracy: 0.9484 - iou_score: 0.3993 - mean_io_u: 0.6261 - iou_coef: 0.8963 - val_loss: 0.9455 - val_accuracy: 0.5255 - val_iou_score: 0.0542 - val_mean_io_u: 0.6258 - val_iou_coef: 0.3495
# Epoch 4/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4973 - accuracy: 0.9637 - iou_score: 0.4987 - mean_io_u: 0.6255 - iou_coef: 0.9276 - val_loss: 0.8304 - val_accuracy: 0.8061 - val_iou_score: 0.1689 - val_mean_io_u: 0.6251 - val_iou_coef: 0.6590
# Epoch 5/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4723 - accuracy: 0.9700 - iou_score: 0.5240 - mean_io_u: 0.6248 - iou_coef: 0.9400 - val_loss: 0.6131 - val_accuracy: 0.9121 - val_iou_score: 0.3858 - val_mean_io_u: 0.6246 - val_iou_coef: 0.8371
# Epoch 6/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4270 - accuracy: 0.9749 - iou_score: 0.5690 - mean_io_u: 0.6243 - iou_coef: 0.9493 - val_loss: 0.5058 - val_accuracy: 0.9375 - val_iou_score: 0.4926 - val_mean_io_u: 0.6241 - val_iou_coef: 0.8817
# Epoch 7/10
# 930/930 [==============================] - 62s 67ms/step - loss: 0.4299 - accuracy: 0.9771 - iou_score: 0.5645 - mean_io_u: 0.6239 - iou_coef: 0.9539 - val_loss: 0.4692 - val_accuracy: 0.9607 - val_iou_score: 0.5291 - val_mean_io_u: 0.6237 - val_iou_coef: 0.9233
# Epoch 8/10
# 930/930 [==============================] - 63s 67ms/step - loss: 0.4204 - accuracy: 0.9783 - iou_score: 0.5750 - mean_io_u: 0.6236 - iou_coef: 0.9567 - val_loss: 0.4277 - val_accuracy: 0.9633 - val_iou_score: 0.5702 - val_mean_io_u: 0.6234 - val_iou_coef: 0.9285
# Epoch 9/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.4098 - accuracy: 0.9813 - iou_score: 0.5866 - mean_io_u: 0.6233 - iou_coef: 0.9625 - val_loss: 0.3932 - val_accuracy: 0.9777 - val_iou_score: 0.6051 - val_mean_io_u: 0.6234 - val_iou_coef: 0.9555
# Epoch 10/10
# 930/930 [==============================] - 63s 68ms/step - loss: 0.1971 - accuracy: 0.9799 - iou_score: 0.7997 - mean_io_u: 0.6240 - iou_coef: 0.9598 - val_loss: 0.2206 - val_accuracy: 0.9743 - val_iou_score: 0.7782 - val_mean_io_u: 0.6246 - val_iou_coef: 0.9494

# %% [markdown]
# # ***Final-long*** training

# %%
# fit model <-> LONG Time If needed
# if you use data generator use model.fit_generator(...) instead of model.fit(...)
# more about `fit_generator` here: https://keras.io/models/sequential/#fit_generator
EPOCHS = 100
n_classes = 43
# lr = ... default attualmente
lr = 0.0019366687517469762
meanIOU = tf.keras.metrics.MeanIoU(num_classes=43)
adam = Adam(learning_rate=lr)
model = sm.Unet(BACKBONE, encoder_weights='imagenet', input_shape = (256, 416, 3), encoder_freeze = True, classes=43, activation='softmax')
model.compile(
    adam,
    loss=sm.losses.JaccardLoss(), #loss = 'categorical_crossentropy',
    metrics = ['accuracy', sm.metrics.IOUScore(), meanIOU, iou_coef] # metrics=[sm.metrics.iou_score]
    )
model.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 416, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 416, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 416, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 128, 208, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 208, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 208, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 64, 104, 128) 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 104, 256) 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 32, 52, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 52, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 16, 26, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 16, 26, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 8, 13, 512)   0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# center_block1_conv (Conv2D)     (None, 8, 13, 512)   2359296     block5_pool[0][0]
# __________________________________________________________________________________________________
# center_block1_bn (BatchNormaliz (None, 8, 13, 512)   2048        center_block1_conv[0][0]
# __________________________________________________________________________________________________
# center_block1_relu (Activation) (None, 8, 13, 512)   0           center_block1_bn[0][0]
# __________________________________________________________________________________________________
# center_block2_conv (Conv2D)     (None, 8, 13, 512)   2359296     center_block1_relu[0][0]
# __________________________________________________________________________________________________
# center_block2_bn (BatchNormaliz (None, 8, 13, 512)   2048        center_block2_conv[0][0]
# __________________________________________________________________________________________________
# center_block2_relu (Activation) (None, 8, 13, 512)   0           center_block2_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 16, 26, 512)  0           center_block2_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 16, 26, 1024) 0           decoder_stage0_upsampling[0][0]
#                                                                  block5_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, 16, 26, 256)  2359296     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 16, 26, 256)  1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 16, 26, 256)  0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, 16, 26, 256)  589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 16, 26, 256)  1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 16, 26, 256)  0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 32, 52, 256)  0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 32, 52, 768)  0           decoder_stage1_upsampling[0][0]
#                                                                  block4_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, 32, 52, 128)  884736      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 32, 52, 128)  512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 32, 52, 128)  0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, 32, 52, 128)  147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 32, 52, 128)  512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 32, 52, 128)  0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 64, 104, 128) 0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 64, 104, 384) 0           decoder_stage2_upsampling[0][0]
#                                                                  block3_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, 64, 104, 64)  221184      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 64, 104, 64)  256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 64, 104, 64)  0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, 64, 104, 64)  36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 64, 104, 64)  256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 64, 104, 64)  0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 128, 208, 64) 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 128, 208, 192 0           decoder_stage3_upsampling[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, 128, 208, 32) 55296       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 128, 208, 32) 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 128, 208, 32) 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, 128, 208, 32) 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 128, 208, 32) 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 128, 208, 32) 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 256, 416, 32) 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, 256, 416, 16) 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 256, 416, 16) 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 256, 416, 16) 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, 256, 416, 16) 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 256, 416, 16) 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 256, 416, 16) 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 256, 416, 43) 6235        decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 256, 416, 43) 0           final_conv[0][0]
# ==================================================================================================
# Total params: 29,068,059
# Trainable params: 9,039,643
# Non-trainable params: 20,028,416
# __________________________________________________________________________________________________

# %%
# funzioni per il salvataggio del miglior modello in riferimento alla metrica
# iou e per il plotting delle curve

logdir = './log3'


checkpoint_filepath = './chekpoint'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_iou_coef',
    mode='max',
    save_best_only=True)
callback_ls = [model_checkpoint_callback,
               TensorBoard(logdir, histogram_freq=1)
               ]

def show_history(history):
    plt.figure(1)
    # plot METRICS
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.plot(history.history['iou_coef'])
    plt.plot(history.history['val_iou_coef'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train_accuracy', 'val_accuracy','iou_coeff','iou_coeff_val'], loc='best')
    #plot LOSSES
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train_loss', 'val_loss'], loc='best')

    plt.show()

# %%
h = model.fit(
    x=X_train,
    y=y_train_norm,
    batch_size=16,
    epochs=EPOCHS,
    validation_data=(X_val,y_val_norm),
    callbacks = callback_ls )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 930 samples, validate on 311 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:198: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
# 930/930 [==============================] - 150s 161ms/step - loss: 0.9307 - accuracy: 0.6915 - iou_score: 0.0700 - mean_io_u: 0.4884 - iou_coef: 0.1559 - val_loss: 0.9892 - val_accuracy: 0.0453 - val_iou_score: 0.0107 - val_mean_io_u: 0.4893 - val_iou_coef: 0.0197

# %%
sio.savemat('./history',{'history':h})

# %%
model.save('./vgg19_unet.h5')

# %%
best_model = load_model('./chekpoint', compile = False)
best_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 416, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 416, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 416, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 128, 208, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 208, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 208, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 64, 104, 128) 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 104, 256) 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 64, 104, 256) 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 32, 52, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 52, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 32, 52, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 16, 26, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 16, 26, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 16, 26, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 8, 13, 512)   0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# center_block1_conv (Conv2D)     (None, 8, 13, 512)   2359296     block5_pool[0][0]
# __________________________________________________________________________________________________
# center_block1_bn (BatchNormaliz (None, 8, 13, 512)   2048        center_block1_conv[0][0]
# __________________________________________________________________________________________________
# center_block1_relu (Activation) (None, 8, 13, 512)   0           center_block1_bn[0][0]
# __________________________________________________________________________________________________
# center_block2_conv (Conv2D)     (None, 8, 13, 512)   2359296     center_block1_relu[0][0]
# __________________________________________________________________________________________________
# center_block2_bn (BatchNormaliz (None, 8, 13, 512)   2048        center_block2_conv[0][0]
# __________________________________________________________________________________________________
# center_block2_relu (Activation) (None, 8, 13, 512)   0           center_block2_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 16, 26, 512)  0           center_block2_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 16, 26, 1024) 0           decoder_stage0_upsampling[0][0]
#                                                                  block5_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, 16, 26, 256)  2359296     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 16, 26, 256)  1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 16, 26, 256)  0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, 16, 26, 256)  589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 16, 26, 256)  1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 16, 26, 256)  0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 32, 52, 256)  0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 32, 52, 768)  0           decoder_stage1_upsampling[0][0]
#                                                                  block4_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, 32, 52, 128)  884736      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 32, 52, 128)  512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 32, 52, 128)  0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, 32, 52, 128)  147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 32, 52, 128)  512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 32, 52, 128)  0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 64, 104, 128) 0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 64, 104, 384) 0           decoder_stage2_upsampling[0][0]
#                                                                  block3_conv4[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, 64, 104, 64)  221184      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 64, 104, 64)  256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 64, 104, 64)  0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, 64, 104, 64)  36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 64, 104, 64)  256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 64, 104, 64)  0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 128, 208, 64) 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 128, 208, 192 0           decoder_stage3_upsampling[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, 128, 208, 32) 55296       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 128, 208, 32) 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 128, 208, 32) 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, 128, 208, 32) 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 128, 208, 32) 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 128, 208, 32) 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 256, 416, 32) 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, 256, 416, 16) 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 256, 416, 16) 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 256, 416, 16) 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, 256, 416, 16) 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 256, 416, 16) 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 256, 416, 16) 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 256, 416, 43) 6235        decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 256, 416, 43) 0           final_conv[0][0]
# ==================================================================================================
# Total params: 29,068,059
# Trainable params: 9,039,643
# Non-trainable params: 20,028,416
# __________________________________________________________________________________________________

# %% [markdown]
# # Show some results

# %%
"""
lr = 0.0019366687517469762
meanIOU = tf.keras.metrics.MeanIoU(num_classes=43)
adam = Adam(learning_rate=lr)
model = sm.Unet(BACKBONE, encoder_weights='imagenet', input_shape = (256, 416, 3), encoder_freeze = True, classes=43, activation='softmax')
model.compile(
    adam,
    loss=sm.losses.JaccardLoss(), #loss = 'categorical_crossentropy',
"""
lr = 0.0019366687517469762
adam = Adam(learning_rate=lr)
best_model.compile(adam, loss = sm.losses.JaccardLoss(), metrics = ['accuracy', sm.metrics.IOUScore(), meanIOU, iou_coef])
best_model.evaluate(x=X_val,y=y_val_norm,batch_size=16) # X_val,y_val_norm
# Out:
# 311/311 [==============================] - 15s 47ms/step
# [0.1612002531431879,
#  0.9851927757263184,
#  0.837109386920929,
#  0.865859866142273,
#  0.9705597162246704]

# %%
def colour_code_segmentation(image, label_values):
    """
    Given a 1-channel array of class keys, colour code the segmentation results.
    # Arguments
        image: single channel array where each value represents the class key.
        label_values
        
    # Returns
        Colour coded image for segmentation visualization
    """
    colour_codes = np.array(label_values)
    x = colour_codes[image.astype(int)]

    return x

# %%
def plot_predictions(X_test,preds,path):
    fig, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12,5))
    ax[0].imshow(X_test,aspect="auto")
    ax[0].set_title("Input")
    ax[1].imshow(preds, aspect="auto")
    ax[1].set_title("Prediction")
    fig.tight_layout()

# %%
#Make predictions
y_prob = model.predict(X_val)

#Output the most probable classes based on predictions
y_classes = y_prob.argmax(axis=-1)

#Reshape our classes in order to proceed with visualizing our predictions
y_classes = y_classes.reshape(y_classes.shape[0],256,416)

#segment = colour_code_segmentation(y_classes,label_values)
#segment=np.squeeze(segment,axis=3)

plot_predictions(X_val[1],y_classes[1],path="3")

# %%
plot_predictions(X_val[3],y_classes[3],path="3")

# %%
plot_predictions(X_val[30],y_classes[30],path="3")

# %%
plot_predictions(X_val[35],y_classes[35],path="3")

# %%
plot_predictions(X_val[43],y_classes[43],path="3")

# %%
plot_predictions(X_val[13],y_classes[13],path="3")

# %%
plot_predictions(X_val[37],y_classes[37],path="3")

# %%
plot_predictions(X_val[39],y_classes[39],path="3")

# %%
y_classes.shape

# %%
y_classes[39,100,300]

# %%
y_classes[37,100,100]
